# %%
import pandas as pd
import pickle
import numpy as np

# %%
file_path = "../data/prod_data.csv"

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#     feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0 -644.527649  64.564857  -4.526694  12.617372  -1.339592   8.432856
# 1 -596.489868  60.752544   1.096842  10.348159  -2.365428   7.986745
# 2 -742.742188  83.390198   6.901477   9.379108   4.036463  14.052815
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_1257  \
# 0  -3.338191  -2.138237  -5.568493  -0.895337  ...      0.000304
# 1  -2.027191  -0.116491  -6.654691  -1.406857  ...      0.000302
# 2   2.257511   1.900848  -0.390256  -4.275728  ...      0.000306
#
#    feature_1258  feature_1259  feature_1260  feature_1261  feature_1262  \
# 0      0.000297      0.000297      0.000341      0.000339      0.000350
# 1      0.000324      0.000330      0.000334      0.000326      0.000337
# 2      0.000295      0.000297      0.000330      0.000329      0.000330
#
#    feature_1263  feature_1264  prediction  confidence
# 0      0.000351      0.000306       angry    0.628934
# ...
